# %% [markdown]
# <a href="https://colab.research.google.com/github/shaon11579/2022-spring-NLP-/blob/main/Synthetic%20data%20generation%20may%2016%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#first we need to install the package
# !pip install sdv
#load a sample dataset
from sdv.demo import load_tabular_demo
data = load_tabular_demo('student_placements')
data.head(20)
# Out:
# Collecting sdv
#   Downloading sdv-0.14.1-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 29.3 MB/s
# Collecting copulas<0.7,>=0.6.1
#   Downloading copulas-0.6.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.8 MB/s
# Collecting graphviz<1,>=0.13.2
#   Downloading graphviz-0.20-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 5.0 MB/s
# Collecting ctgan<0.6,>=0.5.1
#   Downloading ctgan-0.5.1-py2.py3-none-any.whl (24 kB)
# Collecting rdt<0.7,>=0.6.2
#   Downloading rdt-0.6.4-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.7 MB/s
# Collecting sdmetrics<0.5,>=0.4.1
#   Downloading sdmetrics-0.4.1-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.7 MB/s
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.7/dist-packages (from sdv) (4.64.0)
# Requirement already satisfied: pandas<2,>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from sdv) (1.3.5)
# Collecting deepecho<0.4,>=0.3.0.post1
#   Downloading deepecho-0.3.0.post1-py2.py3-none-any.whl (26 kB)
# Collecting Faker<10,>=3.0.0
#   Downloading Faker-9.9.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 39.0 MB/s
# Requirement already satisfied: numpy<2,>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from sdv) (1.21.6)
# Collecting scipy<2,>=1.5.4
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting matplotlib<4,>=3.4.0
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 65.3 MB/s
# Requirement already satisfied: torchvision<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from ctgan<0.6,>=0.5.1->sdv) (0.12.0+cu113)
# Requirement already satisfied: packaging<22,>=20 in /usr/local/lib/python3.7/dist-packages (from ctgan<0.6,>=0.5.1->sdv) (21.3)
# Requirement already satisfied: torch<2,>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from ctgan<0.6,>=0.5.1->sdv) (1.11.0+cu113)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /usr/local/lib/python3.7/dist-packages (from ctgan<0.6,>=0.5.1->sdv) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from Faker<10,>=3.0.0->sdv) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from Faker<10,>=3.0.0->sdv) (4.2.0)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.7/dist-packages (from Faker<10,>=3.0.0->sdv) (1.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.7,>=0.6.1->sdv) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.7,>=0.6.1->sdv) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.7,>=0.6.1->sdv) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 54.2 MB/s
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.7,>=0.6.1->sdv) (3.0.8)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2,>=1.1.3->sdv) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->Faker<10,>=3.0.0->sdv) (1.15.0)
# Collecting psutil<6,>=5.7
#   Downloading psutil-5.9.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 67.4 MB/s
# Collecting pyyaml<6,>=5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 62.3 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<2,>=0.24->ctgan<0.6,>=0.5.1->sdv) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<2,>=0.24->ctgan<0.6,>=0.5.1->sdv) (3.1.0)
# Collecting pyts<0.13.0,>=0.12.0
#   Downloading pyts-0.12.0-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 59.7 MB/s
# Requirement already satisfied: numba>=0.48.0 in /usr/local/lib/python3.7/dist-packages (from pyts<0.13.0,>=0.12.0->sdmetrics<0.5,>=0.4.1->sdv) (0.51.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.48.0->pyts<0.13.0,>=0.12.0->sdmetrics<0.5,>=0.4.1->sdv) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.48.0->pyts<0.13.0,>=0.12.0->sdmetrics<0.5,>=0.4.1->sdv) (57.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.1->sdv) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.1->sdv) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.1->sdv) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.1->sdv) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision<1,>=0.9.0->ctgan<0.6,>=0.5.1->sdv) (2.10)
# Installing collected packages: scipy, fonttools, pyyaml, psutil, matplotlib, rdt, pyts, copulas, sdmetrics, graphviz, Faker, deepecho, ctgan, sdv
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Faker-9.9.1 copulas-0.6.1 ctgan-0.5.1 deepecho-0.3.0.post1 fonttools-4.33.3 graphviz-0.20 matplotlib-3.5.2 psutil-5.9.0 pyts-0.12.0 pyyaml-5.4.1 rdt-0.6.4 scipy-1.7.3 sdmetrics-0.4.1 sdv-0.14.1
#     student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0        17264      M        67.00      91.00  Commerce        58.00
# 1        17265      M        79.33      78.33   Science        77.48
# 2        17266      M        65.00      68.00      Arts        64.00
# 3        17267      M        56.00      52.00   Science        52.00
# 4        17268      M        85.80      73.60  Commerce        73.30
# 5        17269      M        55.00      49.80   Science        67.25
# 6        17270      F        46.00      49.20  Commerce        79.00
# 7        17271      M        82.00      64.00   Science        66.00
# 8        17272      M        73.00      79.00  Commerce        72.00
# 9        17273      M        58.00      70.00  Commerce        61.00
# 10       17274      M        58.00      61.00  Commerce        60.00
# 11       17275      M        69.60      68.40  Commerce        78.30
# 12       17276      F        47.00      55.00   Science        65.00
# 13       17277      F        77.00      87.00  Commerce        59.00
# 14       17278      M        62.00      47.00  Commerce        50.00
# 15       17279      F        65.00      75.00  Commerce        69.00
# 16       17280      M        63.00      66.20  Commerce        65.60
# 17       17281      F        55.00      67.00  Commerce        64.00
# 18       17282      F        63.00      66.00  Commerce        64.00
# 19       17283      M        60.00      67.00      Arts        70.00
#
#    degree_type  work_experience  experience_years  employability_perc  \
# 0     Sci&Tech            False                 0               55.00
# 1     Sci&Tech             True                 1               86.50
# 2    Comm&Mgmt            False                 0               75.00
# 3     Sci&Tech            False                 0               66.00
# 4    Comm&Mgmt            False                 0               96.80
# 5     Sci&Tech             True                 1               55.00
# 6    Comm&Mgmt            False                 0               74.28
# 7     Sci&Tech             True                 1               67.00
# 8    Comm&Mgmt            False                 0               91.34
# 9    Comm&Mgmt            False                 0               54.00
# 10   Comm&Mgmt             True                 1               62.00
# 11   Comm&Mgmt             True                 1               60.00
# 12   Comm&Mgmt            False                 0               62.00
# 13   Comm&Mgmt            False                 0               68.00
# 14   Comm&Mgmt            False                 0               76.00
# 15   Comm&Mgmt             True                 1               72.00
# 16   Comm&Mgmt             True                 1               60.00
# 17   Comm&Mgmt            False                 0               60.00
# 18   Comm&Mgmt            False                 0               68.00
# 19   Comm&Mgmt             True                 1               50.48
#
#    mba_spec  mba_perc   salary  placed start_date   end_date  duration
# 0    Mkt&HR     58.80  27000.0    True 2020-07-23 2020-10-12       3.0
# 1   Mkt&Fin     66.28  20000.0    True 2020-01-11 2020-04-09       3.0
# 2   Mkt&Fin     57.80  25000.0    True 2020-01-26 2020-07-13       6.0
# 3    Mkt&HR     59.43      NaN   False        NaT        NaT       NaN
# 4   Mkt&Fin     55.50  42500.0    True 2020-07-04 2020-09-27       3.0
# 5   Mkt&Fin     51.58      NaN   False        NaT        NaT       NaN
# 6   Mkt&Fin     53.29      NaN   False        NaT        NaT       NaN
# 7   Mkt&Fin     62.14  25200.0    True 2020-01-26 2020-05-01       3.0
# 8   Mkt&Fin     61.29  23100.0    True 2020-01-26 2020-08-07       6.0
# 9   Mkt&Fin     52.21      NaN   False        NaT        NaT       NaN
# 10   Mkt&HR     60.85  26000.0    True 2020-07-06 2020-10-17       3.0
# 11  Mkt&Fin     63.70  25000.0    True 2020-07-03 2020-10-03       3.0
# 12   Mkt&HR     65.04      NaN   False        NaT        NaT       NaN
# 13  Mkt&Fin     68.63  21800.0    True 2020-01-27 2020-05-06       3.0
# 14   Mkt&HR     54.96      NaN   False        NaT        NaT       NaN
# 15  Mkt&Fin     64.66  20000.0    True 2020-07-25 2020-11-05       3.0
# 16  Mkt&Fin     62.54  30000.0    True 2020-01-29 2020-08-09       6.0
# 17  Mkt&Fin     67.28      NaN   False        NaT        NaT       NaN
# 18   Mkt&HR     64.08      NaN   False        NaT        NaT       NaN
# 19  Mkt&Fin     77.89  23600.0    True 2020-01-24 2021-01-08      12.0

# %%
from sdv.tabular import TVAE
model = TVAE()
model.fit(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:146: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   .fit(X)
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:146: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   .fit(X)
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()

# %%
new_data = model.sample(200)
new_data.head(20)
# Out:
#     student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0        17352      M        50.61      87.48  Commerce        68.09
# 1        17264      M        62.49      71.30   Science        59.05
# 2        17325      M        85.97      56.11  Commerce        76.57
# 3        17315      M        62.50      65.99  Commerce        60.69
# 4        17284      M        56.56      79.87  Commerce        67.41
# 5        17291      M        85.29      59.01   Science        61.44
# 6        17396      M        83.86      63.42   Science        73.97
# 7        17264      M        73.54      63.71  Commerce        66.36
# 8        17433      M        59.69      70.88   Science        66.00
# 9        17297      M        58.61      65.50  Commerce        53.94
# 10       17402      M        67.37      44.79   Science        65.80
# 11       17424      M        60.90      67.57  Commerce        67.16
# 12       17309      M        54.59      56.30  Commerce        60.64
# 13       17426      M        64.52      80.36  Commerce        68.85
# 14       17275      M        50.62      78.78  Commerce        73.60
# 15       17326      M        64.66      74.00  Commerce        68.28
# 16       17305      M        62.95      84.23   Science        70.85
# 17       17314      M        79.80      68.15   Science        68.48
# 18       17334      M        62.73      76.48  Commerce        61.86
# 19       17330      M        62.43      65.30  Commerce        62.51
#
#    degree_type  work_experience  experience_years  employability_perc  \
# 0    Comm&Mgmt            False                 0               55.94
# 1    Comm&Mgmt            False                 0               58.10
# 2    Comm&Mgmt            False                 0               53.64
# 3    Comm&Mgmt            False                 0               68.99
# 4    Comm&Mgmt            False                 0               66.65
# 5     Sci&Tech            False                 0               83.82
# 6     Sci&Tech             True                 0               83.62
# 7    Comm&Mgmt            False                 0               98.00
# 8     Sci&Tech             True                 0               56.21
# 9    Comm&Mgmt            False                 0               56.46
# 10   Comm&Mgmt            False                 0               55.97
# 11   Comm&Mgmt            False                 0               67.63
# 12   Comm&Mgmt            False                 0               67.60
# 13   Comm&Mgmt            False                 0               54.25
# 14   Comm&Mgmt            False                 0               56.49
# 15   Comm&Mgmt            False                 0               61.96
# 16   Comm&Mgmt            False                 0               98.00
# 17   Comm&Mgmt             True                 1               89.41
# 18   Comm&Mgmt            False                 0               56.29
# 19   Comm&Mgmt            False                 0               50.00
#
#    mba_spec  mba_perc   salary  placed start_date   end_date  duration
# 0   Mkt&Fin     70.84  21400.0    True 2020-01-22 2020-08-06       6.0
# 1    Mkt&HR     56.29  24700.0    True 2020-01-25 2020-11-04       3.0
# 2    Mkt&HR     59.77  23400.0    True 2020-01-24 2020-12-06       3.0
# 3    Mkt&HR     55.54  30200.0    True 2020-07-28 2020-12-19       3.0
# 4    Mkt&HR     63.23  28000.0    True 2020-01-22 2020-10-22       5.0
# 5    Mkt&HR     58.87  23600.0    True 2020-01-25 2020-10-03       3.0
# 6   Mkt&Fin     73.88  29600.0    True 2020-07-18 2020-10-02       3.0
# 7   Mkt&Fin     62.09  22400.0    True 2020-01-27 2020-05-09       3.0
# 8   Mkt&Fin     54.05  29800.0    True 2020-01-23 2020-12-19       3.0
# 9    Mkt&HR     55.84      NaN   False        NaT        NaT       NaN
# 10   Mkt&HR     58.18      NaN   False 2020-03-07        NaT       NaN
# 11  Mkt&Fin     63.69      NaN   False        NaT        NaT       NaN
# 12   Mkt&HR     55.41      NaN   False        NaT        NaT       NaN
# 13   Mkt&HR     56.48  24900.0    True 2020-01-22 2020-08-19       6.0
# 14  Mkt&Fin     63.24  22600.0    True 2020-01-22 2020-11-05       3.0
# 15  Mkt&Fin     69.77  24500.0    True 2020-01-20 2020-12-08       6.0
# 16   Mkt&HR     63.66  20500.0    True 2020-01-12 2020-03-27       3.0
# 17  Mkt&Fin     61.11  28700.0    True 2020-01-13 2020-09-24       3.0
# 18  Mkt&Fin     67.28  22600.0    True 2020-01-16 2020-07-28       6.0
# 19   Mkt&HR     53.96  27100.0    True 2020-01-10 2020-08-11       6.0

# %%
#save the model
model.save('/bin.pkl')

# %%
#load the model
loaded = TVAE.load('/bin.pkl')
new_data = loaded.sample(200)

# %%
model = TVAE(primary_key='student_id')
model.fit(data)
new_data = model.sample(200)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:146: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   .fit(X)
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:146: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   .fit(X)
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()

# %%
data_pii = load_tabular_demo('student_placements_pii')
data_pii.head(20)
# Out:
#     student_id                                            address gender  \
# 0        17264        70304 Baker Turnpike\nEricborough, MS 15086      M
# 1        17265    805 Herrera Avenue Apt. 134\nMaryview, NJ 36510      M
# 2        17266        3702 Bradley Island\nNorth Victor, FL 12268      M
# 3        17267                   Unit 0879 Box 3878\nDPO AP 42663      M
# 4        17268  96493 Kelly Canyon Apt. 145\nEast Steven, NC 3...      M
# 5        17269                   Unit 7945 Box 5398\nDPO AA 18917      M
# 6        17270           943 Martha Wells\nOwensborough, NC 46065      F
# 7        17271    195 Kevin Parkways Apt. 828\nToddland, TN 54615      M
# 8        17272                   PSC 2024, Box 1677\nAPO AP 99732      M
# 9        17273  336 Davis Drives Apt. 411\nNew Reginashire, CT...      M
# 10       17274  786 Shane Bridge Suite 165\nNorth Douglas, GA ...      M
# 11       17275                          USS Sanchez\nFPO AA 16841      M
# 12       17276  21119 Bailey Mall Apt. 215\nCameronbury, GA 31205      F
# 13       17277                           USNS Ellis\nFPO AP 62042      F
# 14       17278  4210 Baker Stravenue\nNorth Christopher, WI 90462      M
# 15       17279                   PSC 1354, Box 1414\nAPO AA 25325      F
# 16       17280  081 Carrie Square Apt. 439\nJohnsontown, NM 66991      M
# 17       17281         36924 Jamie Cliffs\nPhillipmouth, TX 21393      F
# 18       17282         8065 Williams Lodge\nRichardfurt, MT 35336      F
# 19       17283  87765 William Mews Suite 474\nMichaelhaven, IL...      M
#
#     second_perc  high_perc high_spec  degree_perc degree_type  \
# 0         67.00      91.00  Commerce        58.00    Sci&Tech
# 1         79.33      78.33   Science        77.48    Sci&Tech
# 2         65.00      68.00      Arts        64.00   Comm&Mgmt
# 3         56.00      52.00   Science        52.00    Sci&Tech
# 4         85.80      73.60  Commerce        73.30   Comm&Mgmt
# 5         55.00      49.80   Science        67.25    Sci&Tech
# 6         46.00      49.20  Commerce        79.00   Comm&Mgmt
# 7         82.00      64.00   Science        66.00    Sci&Tech
# 8         73.00      79.00  Commerce        72.00   Comm&Mgmt
# 9         58.00      70.00  Commerce        61.00   Comm&Mgmt
# 10        58.00      61.00  Commerce        60.00   Comm&Mgmt
# 11        69.60      68.40  Commerce        78.30   Comm&Mgmt
# 12        47.00      55.00   Science        65.00   Comm&Mgmt
# 13        77.00      87.00  Commerce        59.00   Comm&Mgmt
# 14        62.00      47.00  Commerce        50.00   Comm&Mgmt
# 15        65.00      75.00  Commerce        69.00   Comm&Mgmt
# 16        63.00      66.20  Commerce        65.60   Comm&Mgmt
# 17        55.00      67.00  Commerce        64.00   Comm&Mgmt
# 18        63.00      66.00  Commerce        64.00   Comm&Mgmt
# 19        60.00      67.00      Arts        70.00   Comm&Mgmt
#
#     work_experience  experience_years  employability_perc mba_spec  mba_perc  \
# 0             False                 0               55.00   Mkt&HR     58.80
# 1              True                 1               86.50  Mkt&Fin     66.28
# 2             False                 0               75.00  Mkt&Fin     57.80
# 3             False                 0               66.00   Mkt&HR     59.43
# 4             False                 0               96.80  Mkt&Fin     55.50
# 5              True                 1               55.00  Mkt&Fin     51.58
# 6             False                 0               74.28  Mkt&Fin     53.29
# 7              True                 1               67.00  Mkt&Fin     62.14
# 8             False                 0               91.34  Mkt&Fin     61.29
# 9             False                 0               54.00  Mkt&Fin     52.21
# 10             True                 1               62.00   Mkt&HR     60.85
# 11             True                 1               60.00  Mkt&Fin     63.70
# 12            False                 0               62.00   Mkt&HR     65.04
# 13            False                 0               68.00  Mkt&Fin     68.63
# 14            False                 0               76.00   Mkt&HR     54.96
# 15             True                 1               72.00  Mkt&Fin     64.66
# 16             True                 1               60.00  Mkt&Fin     62.54
# 17            False                 0               60.00  Mkt&Fin     67.28
# 18            False                 0               68.00   Mkt&HR     64.08
# 19             True                 1               50.48  Mkt&Fin     77.89
#
#      salary  placed start_date   end_date  duration
# 0   27000.0    True 2020-07-23 2020-10-12       3.0
# 1   20000.0    True 2020-01-11 2020-04-09       3.0
# 2   25000.0    True 2020-01-26 2020-07-13       6.0
# 3       NaN   False        NaT        NaT       NaN
# 4   42500.0    True 2020-07-04 2020-09-27       3.0
# 5       NaN   False        NaT        NaT       NaN
# 6       NaN   False        NaT        NaT       NaN
# 7   25200.0    True 2020-01-26 2020-05-01       3.0
# 8   23100.0    True 2020-01-26 2020-08-07       6.0
# 9       NaN   False        NaT        NaT       NaN
# 10  26000.0    True 2020-07-06 2020-10-17       3.0
# 11  25000.0    True 2020-07-03 2020-10-03       3.0
# 12      NaN   False        NaT        NaT       NaN
# 13  21800.0    True 2020-01-27 2020-05-06       3.0
# 14      NaN   False        NaT        NaT       NaN
# 15  20000.0    True 2020-07-25 2020-11-05       3.0
# 16  30000.0    True 2020-01-29 2020-08-09       6.0
# 17      NaN   False        NaT        NaT       NaN
# 18      NaN   False        NaT        NaT       NaN
# 19  23600.0    True 2020-01-24 2021-01-08      12.0

# %%
model = TVAE(primary_key='student_id',anonymize_fields={'address': 'address' })
model.fit(data_pii)
new_data_pii = model.sample(200)
new_data_pii.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:146: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   .fit(X)
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/mixture/_base.py:146: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   .fit(X)
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[col] = igetitem(value, i)
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
# /usr/local/lib/python3.7/dist-packages/ctgan/data_transformer.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column_name] = data[column_name].to_numpy().flatten()
#     student_id                                            address gender  \
# 0            0         575 Griffith Skyway\nJohnsonstad, KY 19906      M
# 1            1       4331 Bryan Inlet\nPort Christopher, CT 40617      M
# 2            2                   Unit 3476 Box 9185\nDPO AA 81241      M
# 3            3  074 Randy Throughway Suite 425\nPort Jason, WY...      M
# 4            4                           USNV Lewis\nFPO AE 33417      M
# 5            5     6227 Jacob Lights\nPort Katrinashire, MI 65114      M
# 6            6  26867 Johnson Viaduct Apt. 962\nWest Craigbury...      M
# 7            7  29509 David Lodge Suite 612\nSandraborough, VA...      M
# 8            8      67008 Jensen Circle\nRodriguezburgh, PA 02075      M
# 9            9                   PSC 6766, Box 9308\nAPO AA 08689      M
# 10          10           5478 Jessica Inlet\nThomasside, NH 09373      F
# 11          11         3069 Cody Fall\nLake Brookemouth, NE 72955      M
# 12          12   7146 Darryl Walks Suite 246\nAlexshire, NE 36487      M
# 13          13      066 Williams Mews\nPort Justinmouth, LA 40347      M
# 14          14           581 Eric Springs\nAndersonport, ME 97469      M
# 15          15      990 Washington Mountains\nLake Eric, MS 67331      M
# 16          16  4659 Kristin Orchard Apt. 870\nPort Leslie, VT...      M
# 17          17      261 Arnold Fort Apt. 930\nColeburgh, MI 43461      M
# 18          18           286 Berger Forges\nSouth Anita, HI 13871      M
# 19          19             2488 Larson Rest\nDanielfurt, MT 48708      M
#
#     second_perc  high_perc high_spec  degree_perc degree_type  \
# 0         74.19      80.32  Commerce        67.41   Comm&Mgmt
# 1         63.87      69.65  Commerce        67.02   Comm&Mgmt
# 2         73.84      64.05   Science        68.09   Comm&Mgmt
# 3         73.35      66.56   Science        63.92   Comm&Mgmt
# 4         60.23      55.58  Commerce        65.39   Comm&Mgmt
# 5         63.57      63.85  Commerce        63.89   Comm&Mgmt
# 6         62.43      60.46  Commerce        66.92   Comm&Mgmt
# 7         69.64      77.18  Commerce        75.15   Comm&Mgmt
# 8         64.28      65.17  Commerce        65.16   Comm&Mgmt
# 9         65.03      61.36  Commerce        56.54   Comm&Mgmt
# 10        77.49      71.48   Science        72.96   Comm&Mgmt
# 11        66.01      78.15  Commerce        69.62   Comm&Mgmt
# 12        65.92      67.47  Commerce        59.38   Comm&Mgmt
# 13        61.63      68.94  Commerce        61.83   Comm&Mgmt
# 14        68.37      60.42  Commerce        67.88   Comm&Mgmt
# 15        65.54      73.70  Commerce        71.97   Comm&Mgmt
# 16        60.29      58.67  Commerce        58.46   Comm&Mgmt
# 17        71.41      72.25  Commerce        65.96   Comm&Mgmt
# 18        63.02      88.32  Commerce        62.34   Comm&Mgmt
# 19        62.56      73.78  Commerce        63.05   Comm&Mgmt
#
#     work_experience  experience_years  employability_perc mba_spec  mba_perc  \
# 0             False                 0               58.86  Mkt&Fin     63.24
# 1             False                 0               61.87  Mkt&Fin     64.02
# 2             False                 0               79.30  Mkt&Fin     69.46
# 3              True                 1               55.49  Mkt&Fin     62.72
# 4             False                 0               58.53  Mkt&Fin     64.21
# 5             False                 0               53.46   Mkt&HR     52.20
# 6             False                 0               57.23   Mkt&HR     55.39
# 7             False                 0               94.13  Mkt&Fin     67.62
# 8             False                 0               83.31   Mkt&HR     60.95
# 9              True                 0               63.11  Mkt&Fin     55.77
# 10            False                 0               91.71  Mkt&Fin     68.02
# 11            False                 0               52.62  Mkt&Fin     62.02
# 12            False                 0               73.07  Mkt&Fin     56.09
# 13             True                 0               82.36  Mkt&Fin     53.93
# 14            False                 0               86.94   Mkt&HR     65.59
# 15             True                 1               59.28  Mkt&Fin     57.21
# 16            False                 0               66.29  Mkt&Fin     59.20
# 17            False                 0               67.60  Mkt&Fin     59.14
# 18            False                 0               58.69   Mkt&HR     54.88
# 19            False                 0               55.70  Mkt&Fin     57.43
#
#      salary  placed start_date   end_date  duration
# 0       NaN    True 2020-01-13 2020-08-08       6.0
# 1   25700.0    True 2020-01-19 2020-07-30       6.0
# 2   27600.0    True 2020-01-14 2020-10-12       3.0
# 3   26800.0    True 2020-01-19 2020-08-05       6.0
# 4       NaN   False        NaT        NaT       NaN
# 5   23300.0    True 2020-07-20 2020-11-23       3.0
# 6   28600.0    True 2020-03-11 2020-08-14       6.0
# 7   28800.0    True 2020-01-25 2020-04-26       3.0
# 8   20500.0    True 2020-01-22 2020-12-04       3.0
# 9   21000.0    True 2020-01-20 2020-07-09       6.0
# 10  22700.0    True 2020-01-09 2020-08-06       6.0
# 11  23800.0    True 2020-01-17 2020-08-25       6.0
# 12  26000.0    True 2020-08-02 2020-10-05       3.0
# 13  26600.0    True 2020-01-25 2020-04-06       3.0
# 14  23200.0    True 2020-07-12 2020-10-12       3.0
# 15  28300.0    True 2020-01-22 2020-07-16       6.0
# 16  24700.0    True 2020-01-27 2020-12-21      12.0
# 17      NaN   False        NaT        NaT       NaN
# 18  29700.0   False        NaT        NaT       NaN
# 19  25400.0    True 2020-01-26 2020-07-30       6.0

# %%
#load the dataset, in our case we can use the built-in demo dataset
from sdv.metrics.demos import load_single_table_demo
real_data, synthetic_data, metadata = load_single_table_demo()

# %% [markdown]
# the metadata is the dictionary representation of the student_placements metadata will look somewhat like this

# %%
{'fields': {'start_date': {'type': 'datetime', 'format': '%Y-%m-%d'},
  'end_date': {'type': 'datetime', 'format': '%Y-%m-%d'},
  'salary': {'type': 'numerical', 'subtype': 'integer'},
  'duration': {'type': 'categorical'},
  'student_id': {'type': 'id', 'subtype': 'integer'},
  'high_perc': {'type': 'numerical', 'subtype': 'float'},
  'high_spec': {'type': 'categorical'},
  'mba_spec': {'type': 'categorical'},
  'second_perc': {'type': 'numerical', 'subtype': 'float'},
  'gender': {'type': 'categorical'},
  'degree_perc': {'type': 'numerical', 'subtype': 'float'},
  'placed': {'type': 'boolean'},
  'experience_years': {'type': 'numerical', 'subtype': 'float'},
  'employability_perc': {'type': 'numerical', 'subtype': 'float'},
  'mba_perc': {'type': 'numerical', 'subtype': 'float'},
  'work_experience': {'type': 'boolean'},
  'degree_type': {'type': 'categorical'}},
 'constraints': [],
 'model_kwargs': {},
 'name': None,
 'primary_key': 'student_id',
 'sequence_index': None,
 'entity_columns': [],
 'context_columns': []}
# Out:
# {'constraints': [],
#  'context_columns': [],
#  'entity_columns': [],
#  'fields': {'degree_perc': {'subtype': 'float', 'type': 'numerical'},
#   'degree_type': {'type': 'categorical'},
#   'duration': {'type': 'categorical'},
#   'employability_perc': {'subtype': 'float', 'type': 'numerical'},
#   'end_date': {'format': '%Y-%m-%d', 'type': 'datetime'},
#   'experience_years': {'subtype': 'float', 'type': 'numerical'},
#   'gender': {'type': 'categorical'},
#   'high_perc': {'subtype': 'float', 'type': 'numerical'},
#   'high_spec': {'type': 'categorical'},
#   'mba_perc': {'subtype': 'float', 'type': 'numerical'},
#   'mba_spec': {'type': 'categorical'},
#   'placed': {'type': 'boolean'},
#   'salary': {'subtype': 'integer', 'type': 'numerical'},
#   'second_perc': {'subtype': 'float', 'type': 'numerical'},
#   'start_date': {'format': '%Y-%m-%d', 'type': 'datetime'},
#   'student_id': {'subtype': 'integer', 'type': 'id'},
#   'work_experience': {'type': 'boolean'}},
#  'model_kwargs': {},
#  'name': None,
#  'primary_key': 'student_id',
#  'sequence_index': None}

# %% [markdown]
# Now further this evaluation is divided into a few different ways to evaluate.
#
# Statistical Metrics: compares the table by running a different statistical test

# %%
from sdv.metrics.tabular import CSTest, KSTest
#KSTest: This metric uses the two-sample Kolmogorov–Smirnov test to #compare the distributions of continuous columns using the empirical #CDF
'''The output for each column is 1 minus the KS Test D statistic, which indicates the maximum distance between the expected CDF and the observed CDF values.'''
KSTest.compute(real_data, synthetic_data)
#CSTest: uses Chi-Squared test to compare the distributions of two #discrete columns, the output will be in p-value which is the probability of two columns having been sampled from the 
#sample distribution.
CSTest.compute(real_data, synthetic_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sdmetrics/utils.py:62: UserWarning: Unexpected value nan in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# 0.8078084931103922

# %% [markdown]
# we can do KSTest and CSTest it in one shot using evaluate

# %%
from sdv.evaluation import evaluate
evaluate(synthetic_data, real_data, metrics=['CSTest', 'KSTest'], aggregate=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sdmetrics/utils.py:62: UserWarning: Unexpected value nan in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
#    metric                                     name  raw_score  \
# 0  CSTest                              Chi-Squared   0.807808
# 1  KSTest  Inverted Kolmogorov-Smirnov D statistic   0.637209
#
#    normalized_score  min_value  max_value      goal error
# 0          0.807808        0.0        1.0  MAXIMIZE  None
# 1          0.637209        0.0        1.0  MAXIMIZE  None

# %% [markdown]
# 2. Likelihood Metrics

# %%
#pip install pomegranate to run the below packages
from sdv.metrics.tabular import BNLikelihood, BNLogLikelihood, GMLogLikelihood 
#this metric fits a BayesiaNetwork to the real data and then #evaluates the average likelihood of the rows from the synthetic #data on it.
BNLikelihood.compute(real_data.fillna(0), synthetic_data.fillna(0))
 
#the same as above but here we taking log into consideration, so it #will be the average log likelihood
raw_score1 = BNLogLikelihood.compute(real_data.fillna(0), synthetic_data.fillna(0))
 
#This metric will use GaussianMixture addition to average log #likelihood
raw_score2 = GMLogLikelihood.compute(real_data.fillna(0), synthetic_data.fillna(0))
#we can normalize our results between 0 and 1 by simply using the #normalize method instead of using the likelihood scores 
BNLogLikelihood.normalize(raw_score1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sdmetrics/single_table/bayesian_network.py in _likelihoods(cls, real_data, synthetic_data, metadata, structure)
#      40         try:
# ---> 41             from pomegranate import BayesianNetwork
#      42         except ImportError:
#
# ModuleNotFoundError: No module named 'pomegranate'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-52d015635c5b> in <module>()
#       2 from sdv.metrics.tabular import BNLikelihood, BNLogLikelihood, GMLogLikelihood
#       3 #this metric fits a BayesiaNetwork to the real data and then #evaluates the average likelihood of the rows from the synthetic #data on it.
# ----> 4 BNLikelihood.compute(real_data.fillna(0), synthetic_data.fillna(0))
#       5
#       6 #the same as above but here we taking log into consideration, so it #will be the average log likelihood
#
# /usr/local/lib/python3.7/dist-packages/sdmetrics/single_table/bayesian_network.py in compute(cls, real_data, synthetic_data, metadata, structure)
#     114                 Mean of the probabilities returned by the Bayesian Network.
#     115         """
# --> 116         return np.mean(cls._likelihoods(real_data, synthetic_data, metadata, structure))
#     117
#     118
#
# /usr/local/lib/python3.7/dist-packages/sdmetrics/single_table/bayesian_network.py in _likelihoods(cls, real_data, synthetic_data, metadata, structure)
#      41             from pomegranate import BayesianNetwork
#      42         except ImportError:
# ---> 43             raise ImportError('Please install pomegranate with `pip install pomegranate`')
#      44
#      45         metadata = cls._validate_inputs(real_data, synthetic_data, metadata)
#
# ImportError: Please install pomegranate with `pip install pomegranate`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pomegranate
# Out:
# Collecting pomegranate
#   Downloading pomegranate-0.14.8.tar.gz (4.3 MB)
#      |████████████████████████████████| 4.3 MB 26.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pomegranate) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from pomegranate) (5.4.1)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.7/dist-packages (from pomegranate) (2.6.3)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.7/dist-packages (from pomegranate) (1.1.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from pomegranate) (1.7.3)
# Building wheels for collected packages: pomegranate
#   Building wheel for pomegranate (PEP 517) ... done
#   Created wheel for pomegranate: filename=pomegranate-0.14.8-cp37-cp37m-linux_x86_64.whl size=15006508 sha256=495bb201402a889306bea73d23f328d94bcd09902b172bf05d8f8f98e84444a9
#   Stored in directory: /root/.cache/pip/wheels/24/68/69/0eaab474ef1d65abedcd47de8a38ab21d221d329954d7edd24
# Successfully built pomegranate
# Installing collected packages: pomegranate
# Successfully installed pomegranate-0.14.8

# %% [markdown]
# 3. Detection Metrics: tries to distinguish how hard it is the synthetic data from the real data using the machine-learning model.
# The output will be in 1 minus the average ROC AUC score across all the cross-validation splits

# %%
from sdv.metrics.tabular import LogisticDetection, SVCDetection
LogisticDetection.compute(real_data, synthetic_data)
SVCDetection.compute(real_data, synthetic_data)
# Out:
# 0.0012896307888482506

# %% [markdown]
# 4. Machine Learning Efficacy Metrics: These metrics will evaluate whether it is possible to replace the real data with synthetic data in order to solve a Machine Learning Problem by learning a Machine Learning model on the synthetic data and then evaluating the score which it obtains when evaluated on the real data.

# %%
from sdv.metrics.tabular import MulticlassDecisionTreeClassifier
MulticlassDecisionTreeClassifier.compute(real_data, synthetic_data, target='mba_spec')
# Out:
# 0.5346320346320346

# %% [markdown]
# The output value does not only depend on how good our synthetic data is, but also on how hard the machine learning problem that we are trying to solve is. For instance, we may also compare each model's results with real data and synthetic data.
#
# 5. Privacy Metrics: These metrics measure the privacy of the synthetic dataset identical to the real data. The models accomplish this by fitting an adversarial attacker model on the synthetic data to predict sensitive attributes from “key” attributes and then evaluating its accuracy on the real data.

# %%
#the metrics do not accept missing values, so we will replace or #drop for this example
real_data = real_data.fillna(0, inplace=True)
real_data.isnull().sum()
from sdv.metrics.tabular import NumericalLR
NumericalLR.compute(real_data,synthetic_data,key_fields=
['second_perc', 'mba_perc', 'degree_perc'],
sensitive_fields=['salary'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e301605ae0b9> in <module>()
#       1 #the metrics do not accept missing values, so we will replace or #drop for this example
# ----> 2 real_data = real_data.fillna(0, inplace=True)
#       3 real_data.isnull().sum()
#       4 from sdv.metrics.tabular import NumericalLR
#       5 NumericalLR.compute(real_data,synthetic_data,key_fields=
#
# NameError: name 'real_data' is not defined
